# %% [markdown]
# # Q1 What are the differences among vector, matrix, data frame, and factor

# %% [markdown]
# ## Vectors
# ### Basic datatype in R. All values in a vector must have the same mode (Integer, String, etc).

# %%
#simple numeric vector in R
test_vector <- c(1,2,3,4)
test_vector
# Out:
# [1] 1 2 3 4

# %% [markdown]
# ## Matrices
# ### Multi dimensional, each row of a matrix is a vector. All elements of a matrix must have the same mode.

# %%
# you can insert a vector to a matrix by rows. we'll add the previously created vector to the matrix
cells = test_vector
cols = c("C1","C2")
rows = c("R1", "R2")

#a has 4 values and the matrix below is 2 * 2. Set byrow to TRUE to add each element of a vector row wise 
test_matrix = matrix(cells, nrow = 2, ncol = 2, byrow = TRUE, dimnames = list(rows, cols))
test_matrix
# Out:
#    C1 C2
# R1 1  2
# R2 3  4

# %%
#Access first column of the matrix. They're all integers
test_matrix[,1]
# Out:
# R1 R2
#  1  3

# %%
#Let's insert another column of just strings to the matrix which has only integers
test_matrix = cbind(test_matrix, airport = c("PHX","SFO"))
test_matrix
# Out:
#    C1 C2 airport
# R1 1  2  PHX
# R2 3  4  SFO

# %%
#now when we try to access the first column, we see that the integers have been type-casted to chr
#which is undesirable
test_matrix[,1]
# Out:
#  R1  R2
# "1" "3"

# %% [markdown]
# ## Factors
# ### vectors used to represent categories. Can be used for statistical modeling and classification. Factor is simply a vector whose unique values are called 'levels' which signify nominal or categorical data.

# %%
#create a regular vector with redundant values and check if it's a factor. 
data = c("Student", "Student","Prof","RA","TA","RA","Student","TA","Prof")
is.factor(data)
# Out:
# [1] FALSE

# %%
#convert data to a factor type and print levels (categories)
factor_data = factor(data)
factor_data
# Out:
# [1] Student Student Prof    RA      TA      RA      Student TA      Prof
# Levels: Prof RA Student TA

# %% [markdown]
# ## Dataframes
# ### Dataframes are similar to matrics except each column can be of a different type. one column's mode will not affect the rest of the columns. Columns can be of mode Integer, Chr and Factors

# %%
#insert 3 columns. names(char), id(int), gender(factor)
names = c("John", "Mary", "Anna")
id = c(3, 6, 9)
gender = factor(c('M', 'F', 'F'))
test_df = data.frame(id, names, gender, stringsAsFactors = F)

#when printing the dataframe, we see each column has retained its original mode
test_df
# Out:
#   id names gender
# 1 3  John  M
# 2 6  Mary  F
# 3 9  Anna  F

# %% [markdown]
# ---

# %% [markdown]
# # ggplot Do it yourself questions

# %%
library(ggplot2)
library(gdata)
library(ggrepel)

# %%
sample_file = read.csv("sample.csv")
p = ggplot(sample_file, aes(winner, error))

# %% [markdown]
# ### set figure background to white

# %%
p + geom_point(aes(shape=factor(victory), size=total)) +
    geom_text(aes(colour=factor(year),label=player), position = position_jitter(width=5, height=1.5)) + 
    facet_grid(~year) +
    theme(panel.background = element_rect(fill='white')) #setting background to white with theme function
# Out:
# plot without title

# %% [markdown]
# ### Connect each pair by year with a line

# %%
p + geom_point(aes(shape=factor(victory), size=total)) +
    geom_text_repel(aes(colour=factor(year),label=player), 
              position = position_jitter(width=5, height=1.5)) + 
    facet_grid(~year) +
    theme(panel.background = element_rect(fill='white')) +
    geom_line() #line between each point by year
# Out:
# plot without title

# %% [markdown]
# ### generate charts not by variable, by columns

# %%
p + 
geom_point(aes(shape=factor(victory), size=total)) +
geom_text_repel(aes(colour=factor(year),label=player), 
          position = position_jitter(width=5, height=1.5), 
          size=3) + 
facet_wrap(~year, ncol = 2) + #facet wrap with year and set columns to 2 to get sub charts
theme(panel.background = element_rect(fill='white')) +
geom_line()
# Out:
# plot without title

# %%
sample_file
# Out:
#    year player             victory winner error total
# 1  2009 Rafael Nadal       1       50     41    173
# 2  2009 Roger Federer      0       71     64    174
# 3  2010 Roger Federer      1       46     42    116
# 4  2010 Andy Murray        0       29     36    100
# 5  2011 Novak Djokovic     1       26     33    106
# 6  2011 Andy Murray        0       21     47     78
# 7  2012 Novak Djokovic     1       57     69    193
# 8  2012 Rafael Nadal       0       44     71    176
# 9  2013 Novak Djokovic     1       47     61    139
# 10 2013 Andy Murray        0       29     46    126
# 11 2005 Marat Safin        1       54     36    122
# 12 2005 Lleyton Hewitt     0       33     22    113
# 13 2006 Roger Federer      1       50     48    142
# 14 2006 Marcos Baghdatis   0       34     48    116
# 15 2007 Roger Federer      1       45     19    120
# 16 2007 Fernando Gonzalez  0       31     28     93
# 17 2008 Novak Djokovic     1       46     35    136
# 18 2008 Jo-Wilfried Tsonga 0       44     41    122
# 19 2014 Stanislas Wawrinka 1       53     49    116
# 20 2014 Rafael Nadal       0       19     32     88

# %%
p = ggplot(sample_file, aes(winner, error))

p + 
geom_point(aes(shape=factor(victory), size=total)) +
geom_text_repel(aes(colour=factor(year),label=player), size=3) + 
facet_wrap(~year, ncol = 2) + #facet wrap with year and set columns to 2 to get sub charts
theme(panel.background = element_rect(fill='white')) +
geom_line()
# Out:
# plot without title

# %%
p = ggplot(sample_file, aes(year, winner))


p + 
geom_point(aes(shape=factor(victory), size=total)) +
geom_text_repel(aes(colour=factor(year),label=year), size=3) +
facet_wrap(~player, ncol = 2) +
geom_line()
# Out:
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# plot without title

# %%
# Out:
#    year player             victory winner error total
# 1  2009 Rafael Nadal       1       50     41    173
# 2  2009 Roger Federer      0       71     64    174
# 3  2010 Roger Federer      1       46     42    116
# 4  2010 Andy Murray        0       29     36    100
# 5  2011 Novak Djokovic     1       26     33    106
# 6  2011 Andy Murray        0       21     47     78
# 7  2012 Novak Djokovic     1       57     69    193
# 8  2012 Rafael Nadal       0       44     71    176
# 9  2013 Novak Djokovic     1       47     61    139
# 10 2013 Andy Murray        0       29     46    126
# 11 2005 Marat Safin        1       54     36    122
# 12 2005 Lleyton Hewitt     0       33     22    113
# 13 2006 Roger Federer      1       50     48    142
# 14 2006 Marcos Baghdatis   0       34     48    116
# 15 2007 Roger Federer      1       45     19    120
# 16 2007 Fernando Gonzalez  0       31     28     93
# 17 2008 Novak Djokovic     1       46     35    136
# 18 2008 Jo-Wilfried Tsonga 0       44     41    122
# 19 2014 Stanislas Wawrinka 1       53     49    116
# 20 2014 Rafael Nadal       0       19     32     88

# %%
ed_exp3 <- education[which(education$Region == 2),names(education) %in% c("State","Minor.Population","Education.Expenditures")]

# %%
k = sample_file[sample_file$year == 2008, sample_file$player != 'Novak Djokovic']
k
# Out:
# Error in `[.data.frame`(sample_file, sample_file$player != "Novak Djokovic"): undefined columns selected
# Traceback:
#
# 1. sample_file[sample_file$player != "Novak Djokovic"]
# 2. `[.data.frame`(sample_file, sample_file$player != "Novak Djokovic")
# 3. stop("undefined columns selected")

# %%
as.character(subset(sample_file, sample_file$year == 2008 & sample_file$player != 'Novak Djokovic')$player)
# Out:
# [1] "Jo-Wilfried Tsonga"

# %%
as.character(k)
# Out:
# [1] "Jo-Wilfried Tsonga"

# %%
func = function(p_year, p_player) {
    test = as.character(
        subset(sample_file, sample_file$year == p_year & sample_file$player != p_player)$player
    )
    return(test)

}

# %%
transform(sample_file, player2=func(year, as.character(player)))
# Out:
# [1] "double"
# [1] "character"
#    year player             victory winner error total player2
# 1  2009 Rafael Nadal       1       50     41    173   NA
# 2  2009 Roger Federer      0       71     64    174   NA
# 3  2010 Roger Federer      1       46     42    116   NA
# 4  2010 Andy Murray        0       29     36    100   NA
# 5  2011 Novak Djokovic     1       26     33    106   NA
# 6  2011 Andy Murray        0       21     47     78   NA
# 7  2012 Novak Djokovic     1       57     69    193   NA
# 8  2012 Rafael Nadal       0       44     71    176   NA
# 9  2013 Novak Djokovic     1       47     61    139   NA
# 10 2013 Andy Murray        0       29     46    126   NA
# 11 2005 Marat Safin        1       54     36    122   NA
# 12 2005 Lleyton Hewitt     0       33     22    113   NA
# 13 2006 Roger Federer      1       50     48    142   NA
# 14 2006 Marcos Baghdatis   0       34     48    116   NA
# 15 2007 Roger Federer      1       45     19    120   NA
# 16 2007 Fernando Gonzalez  0       31     28     93   NA
# 17 2008 Novak Djokovic     1       46     35    136   NA
# 18 2008 Jo-Wilfried Tsonga 0       44     41    122   NA
# 19 2014 Stanislas Wawrinka 1       53     49    116   NA
# 20 2014 Rafael Nadal       0       19     32     88   NA

# %%
subset(sample_file, sample_file$year == as.character(year) & sample_file$player != toString('sas'))$player
# Out:
#  [1] Rafael Nadal       Roger Federer      Roger Federer      Andy Murray
#  [5] Novak Djokovic     Andy Murray        Novak Djokovic     Rafael Nadal
#  [9] Novak Djokovic     Andy Murray        Marat Safin        Lleyton Hewitt
# [13] Roger Federer      Marcos Baghdatis   Roger Federer      Fernando Gonzalez
# [17] Novak Djokovic     Jo-Wilfried Tsonga Stanislas Wawrinka Rafael Nadal
# 10 Levels: Andy Murray Fernando Gonzalez Jo-Wilfried Tsonga ... Stanislas Wawrinka

# %%
k = 'sas'

# %%
typeof(k)
# Out:
# [1] "character"

# %%
year = 2009

# %%
p_year
# Out:
# Error in eval(expr, envir, enclos): object 'p_year' not found
# Traceback:

# %%
filter(sample_file, year==2009)
# Out:
#    [,1] [,2] [,3] [,4] [,5] [,6] [,7]
#  1 2009  8   1    50   41   173  NA
#  2 2009  9   0    71   64   174  NA
#  3 2010  9   1    46   42   116  NA
#  4 2010  1   0    29   36   100  NA
#  5 2011  7   1    26   33   106  NA
#  6 2011  1   0    21   47    78  NA
#  7 2012  7   1    57   69   193  NA
#  8 2012  8   0    44   71   176  NA
#  9 2013  7   1    47   61   139  NA
# 10 2013  1   0    29   46   126  NA
# 11 2005  5   1    54   36   122  NA
# 12 2005  4   0    33   22   113  NA
# 13 2006  9   1    50   48   142  NA
# 14 2006  6   0    34   48   116  NA
# 15 2007  9   1    45   19   120  NA
# 16 2007  2   0    31   28    93  NA
# 17 2008  7   1    46   35   136  NA
# 18 2008  3   0    44   41   122  NA
# 19 2014 10   1    53   49   116  NA
# 20 2014  8   0    19   32    88  NA
